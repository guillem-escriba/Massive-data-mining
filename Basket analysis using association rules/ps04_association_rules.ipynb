# %% [markdown]
# # Practice Session 04: Basket analysis

# %% [markdown]
# <font size="+2" color="blue">Additional results: experiments on cross-department association rules</font>
#
# Author: <font color="blue">Guillem Escriba Molto</font>
#
# E-mail: <font color="blue">guillem.escriba01@estudiant.upf.edu</font>
#
# Date: <font color="blue">20/10/2022</font>

# %%
# Installation of apyori
# !pip install apyori 3
# Out:
# Requirement already satisfied: apyori in e:\programfiles\anaconda3\lib\site-packages (1.1.2)
# Requirement already satisfied: 3 in e:\programfiles\anaconda3\lib\site-packages (0.0.0)

# %%
import numpy as np  
import matplotlib.pyplot as plt  
import pandas as pd  
import csv
import gzip
from apyori import apriori

# %% [markdown]
# # 1. Playing with apyori

# %%
# LEAVE AS-IS

def print_apyori_output (association_results, info=False, info_key=False):
    for relation_record in association_results:
        itemset = list(relation_record.items)
        
        # Consider only itemsets of two elements
        if len(itemset) > 1: 
        
            print("Rules involving itemset %s" % itemset)
            support = relation_record.support

            for rules in relation_record.ordered_statistics:
                antecedent = list(rules.items_base)
                consequent = list(rules.items_add)
                
                if info_key:
                    antecedent = [info.loc[x][info_key] for x in antecedent]
                    consequent = [info.loc[x][info_key] for x in consequent]
                
                confidence = rules.confidence
                lift = rules.lift

                print("%s => %s (support=%.4f, confidence=%.2f, lift=%.2f)" %
                      (antecedent, consequent, support, confidence, lift))
            print()

# %%
transactions = [
    ['beer', 'chips', 'nuts', 'olives'],
    ['beer', 'chips', 'olives'],
    ['chips', 'nuts' ],
    ['chips', 'olives'],
    ['beer', 'nuts' ],
    ['chips'],
    ['nuts', 'olives'],
    ['beer', 'nuts'],
    ['beer', 'chips', 'olives'], 
    ['beer', 'nuts', 'olives'], 

]
results = list(apriori(transactions, min_support=0.2, min_confidence=1.0, min_lift=1.0))
print_apyori_output(results)
# Out:
# Rules involving itemset ['chips', 'beer', 'olives']
# ['chips', 'beer'] => ['olives'] (support=0.3000, confidence=1.00, lift=1.67)

# %%
transactions = [
    ['beer', 'chips', 'nuts', 'olives'],
    ['beer', 'chips', 'olives'],
    ['beer', 'chips', 'nuts', 'olives'],
    ['chips', 'nuts' ],
    ['beer', 'chips', 'olives'], 
    ['chips', 'olives'],
    ['beer', 'nuts' ],
    ['beer', 'chips', 'nuts', 'olives'],
    ['chips', 'nuts' ],
    ['chips'],
    ['chips', 'nuts' ],
    ['beer', 'chips', 'olives'], 
    ['chips'],
    ['nuts', 'olives'],
    ['beer', 'nuts'],
    ['beer', 'chips', 'olives'], 
    ['beer', 'nuts', 'olives'], 
    ['beer', 'chips', 'nuts', 'olives'],
    ['beer', 'chips', 'nuts', 'olives'],
    ['beer', 'chips', 'olives'],
    ['chips', 'nuts' ],
    ['chips', 'olives'],
    ['beer', 'nuts' ],
    ['chips'],
    ['chips', 'nuts' ],
    ['chips', 'nuts' ],
    ['nuts', 'olives'],
    ['beer', 'nuts'],
    ['beer', 'chips', 'olives'], 
    ['beer', 'nuts', 'olives'], 

]
results = list(apriori(transactions, min_support=0.36, min_confidence=0.76, min_lift=1.35))
print_apyori_output(results)
# Out:
# Rules involving itemset ['chips', 'beer', 'olives']
# ['chips', 'beer'] => ['olives'] (support=0.3667, confidence=1.00, lift=1.76)
# ['chips', 'olives'] => ['beer'] (support=0.3667, confidence=0.85, lift=1.49)

# %% [markdown]
# <font size="+1">For the first rule I would count how many transactions contain "chips" and "beer" (11) and then I would divide it by the total amount of transactions (30) so we obtain 11/30, I would do the same for the second rule but instead of using "chips" and "beer" I'd use "olives" and "chips" so it would be 11/30 too. For compute the confidence I would count how many transactions contain A = "chips" and "beer" which is 11 and how many of them also contain B = "olives" (11) so to compute the confidence we divide transactions with A and B by transactions with A so we get 11/11 this means that every time that "chips" and "beer" has been bought, "olives" have been bought also. The same for the second rule but now A and B are only 11 and A are 13 so we get 11/13 as confidence. Lastly to obtain the lift of the first rule we need to count how many times appear B = "olives" that are 17 and dividing by total trandactions to obtain the support of B that is 17/30 and then we divide the confidence computed previously by that support obtaining (11/11)/(17/30) = 1'76 that is the lift. For the second rule we do the same, first compute the support of B = "beer" which is 17/30 too and then we divide the confidence of A->B by the support B and we obtain (11/13)/(17/30) = 1'49 obtaining the lift.</font>

# %% [markdown]
# # 2. Load and prepare the shopping baskets

# %%
# LEAVE AS-IS

# File names
INPUT_PRODUCTS = "instacart-products.csv"
INPUT_TRANSACTIONS = "instacart-transactions.csv.gz"

# Read into a dataframe
products = pd.read_csv(INPUT_PRODUCTS, delimiter=",")

# Set product_id as index, and drop column aisle_id
products = products.set_index('product_id').drop(columns=['aisle_id'])

products.head(100)
# Out:
#                                                  product_name  department_id
# product_id
# 1                                  Chocolate Sandwich Cookies             19
# 2                                            All-Seasons Salt             13
# 3                        Robust Golden Unsweetened Oolong Tea              7
# 4           Smart Ones Classic Favorites Mini Rigatoni Wit...              1
# 5                                   Green Chile Anytime Sauce             13
# ...                                                       ...            ...
# 96                    Sprinklez Confetti Fun Organic Toppings             13
# 97                                Organic Chamomile Lemon Tea              7
# 98                                  2% Yellow American Cheese             16
# 99                                Local Living Butter Lettuce              4
# 100                   Peanut Butter & Strawberry Jam Sandwich              1
#
# [100 rows x 2 columns]

# %% [markdown]
# ## 2.1. Select by department

# %% [markdown]
# As this file is large and complex, we will focus on one or two departments and try to get some conclusions about the products in those departments. The following cell, which you should leave as-is, list some department names.
#
# <font size="-1" color="gray">(Remove this cell when delivering.)</font>

# %%
# LEAVE AS-IS

DEPT_BAKERY = 3
DEPT_VEGGIES = 4
DEPT_ALCOHOL = 5
DEPT_WORLD = 6
DEPT_DRINKS = 7
DEPT_PETS = 8
DEPT_PHARMACY = 11
DEPT_CLEANING = 17
DEPT_BABIES = 18

# %%
def select_from_departments(products,product_ids,department_ids): # Main function to avoid unnecesary prints
    selected_products = [] # Store the products belonging to the selected departments
    for product_id in product_ids: # Iterates for each product
        if products.loc[product_id].department_id in department_ids: # Checks if the product belongs to the selected departments
            selected_products.append(product_id) # Store in a list
    return selected_products

# %%
def select_from_departments_print(products,product_ids,department_ids): # Function created to print the results for debugging
    selected_products = []
    print("Test case: \n{}\n\nInput products:".format(product_ids))
    for product_id in product_ids:
        print("{} {} (dept {})".format(product_id,products.loc[product_id].product_name,products.loc[product_id].department_id))
        if products.loc[product_id].department_id in department_ids:
            selected_products.append(product_id)
    print("\nSelected products:")
    for product_id in selected_products:
        print("{} {} (dept {})".format(product_id,products.loc[product_id].product_name,products.loc[product_id].department_id))
    return selected_products

# %%
product_ids = [21, 26, 45, 54, 57, 71, 111, 112]
department_ids = [DEPT_PETS, DEPT_CLEANING]
selected_products = select_from_departments_print(products,product_ids,department_ids)
# Out:
# Test case:
# [21, 26, 45, 54, 57, 71, 111, 112]
#
# Input products:
# 21 Small & Medium Dental Dog Treats (dept 8)
# 26 Fancy Feast Trout Feast Flaked Wet Cat Food (dept 8)
# 45 European Cucumber (dept 4)
# 54 24/7 Performance Cat Litter (dept 8)
# 57 Flat Toothpicks (dept 17)
# 71 Ultra 7 Inch Polypropylene Traditional Plates (dept 17)
# 111 Fabric Softener, Geranium Scent (dept 17)
# 112 Hot Tomatillo Salsa (dept 13)
#
# Selected products:
# 21 Small & Medium Dental Dog Treats (dept 8)
# 26 Fancy Feast Trout Feast Flaked Wet Cat Food (dept 8)
# 54 24/7 Performance Cat Litter (dept 8)
# 57 Flat Toothpicks (dept 17)
# 71 Ultra 7 Inch Polypropylene Traditional Plates (dept 17)
# 111 Fabric Softener, Geranium Scent (dept 17)

# %%
# 1 Department
product_ids = [21, 26, 45, 54, 57, 71, 99, 111, 112]
department_ids = [DEPT_ALCOHOL]
selected_products = select_from_departments_print(products,product_ids,department_ids)
# Out:
# Test case:
# [21, 26, 45, 54, 57, 71, 99, 111, 112]
#
# Input products:
# 21 Small & Medium Dental Dog Treats (dept 8)
# 26 Fancy Feast Trout Feast Flaked Wet Cat Food (dept 8)
# 45 European Cucumber (dept 4)
# 54 24/7 Performance Cat Litter (dept 8)
# 57 Flat Toothpicks (dept 17)
# 71 Ultra 7 Inch Polypropylene Traditional Plates (dept 17)
# 99 Local Living Butter Lettuce (dept 4)
# 111 Fabric Softener, Geranium Scent (dept 17)
# 112 Hot Tomatillo Salsa (dept 13)
#
# Selected products:

# %%
# 2 Department
product_ids = [3, 4, 21, 26, 45, 54, 57, 71, 97, 99, 111, 112]
department_ids = [DEPT_ALCOHOL, DEPT_DRINKS]
selected_products = select_from_departments_print(products,product_ids,department_ids)
# Out:
# Test case:
# [3, 4, 21, 26, 45, 54, 57, 71, 97, 99, 111, 112]
#
# Input products:
# 3 Robust Golden Unsweetened Oolong Tea (dept 7)
# 4 Smart Ones Classic Favorites Mini Rigatoni With Vodka Cream Sauce (dept 1)
# 21 Small & Medium Dental Dog Treats (dept 8)
# 26 Fancy Feast Trout Feast Flaked Wet Cat Food (dept 8)
# 45 European Cucumber (dept 4)
# 54 24/7 Performance Cat Litter (dept 8)
# 57 Flat Toothpicks (dept 17)
# 71 Ultra 7 Inch Polypropylene Traditional Plates (dept 17)
# 97 Organic Chamomile Lemon Tea (dept 7)
# 99 Local Living Butter Lettuce (dept 4)
# 111 Fabric Softener, Geranium Scent (dept 17)
# 112 Hot Tomatillo Salsa (dept 13)
#
# Selected products:
# 3 Robust Golden Unsweetened Oolong Tea (dept 7)
# 97 Organic Chamomile Lemon Tea (dept 7)

# %%
# 3 Departments
product_ids = [21, 26, 45, 54, 57, 71, 99, 111, 112]
department_ids = [DEPT_PETS, DEPT_CLEANING, DEPT_VEGGIES]
selected_products = select_from_departments_print(products,product_ids,department_ids)
# Out:
# Test case:
# [21, 26, 45, 54, 57, 71, 99, 111, 112]
#
# Input products:
# 21 Small & Medium Dental Dog Treats (dept 8)
# 26 Fancy Feast Trout Feast Flaked Wet Cat Food (dept 8)
# 45 European Cucumber (dept 4)
# 54 24/7 Performance Cat Litter (dept 8)
# 57 Flat Toothpicks (dept 17)
# 71 Ultra 7 Inch Polypropylene Traditional Plates (dept 17)
# 99 Local Living Butter Lettuce (dept 4)
# 111 Fabric Softener, Geranium Scent (dept 17)
# 112 Hot Tomatillo Salsa (dept 13)
#
# Selected products:
# 21 Small & Medium Dental Dog Treats (dept 8)
# 26 Fancy Feast Trout Feast Flaked Wet Cat Food (dept 8)
# 45 European Cucumber (dept 4)
# 54 24/7 Performance Cat Litter (dept 8)
# 57 Flat Toothpicks (dept 17)
# 71 Ultra 7 Inch Polypropylene Traditional Plates (dept 17)
# 99 Local Living Butter Lettuce (dept 4)
# 111 Fabric Softener, Geranium Scent (dept 17)

# %% [markdown]
# ## 2.2. Read and filter transactions

# %%
def extract_transactions(filename,products,department_ids):
    transactions = []
    n_read = 0
    n_stored = 0
    # Open a compressed file
    with gzip.open(INPUT_TRANSACTIONS, "rt") as inputfile:

        # Create a CSV reader
        reader = csv.reader(inputfile, delimiter=",")

        # Iterate through the CSV file
        for row in reader:
            n_read += 1
            if n_read%1000 == 0:
                print("\nNumber of transactions read: {}\nNumer of transactions stored: {}/5000 ({}%)".format(n_read,n_stored,round((n_stored/5000)*100,2)))
            # Convert to integers
            items = [int(x) for x in row]
            selected_items = select_from_departments(products,items,department_ids)
            if len(selected_items) > 1:
                transactions.append(selected_items)
                n_stored += 1
            if n_stored == 5000:
                print("\nNumber of transactions read: {}\nNumer of transactions stored: {}/5000 ({}%)\n\nTransactions extracted succesfuly!".format(n_read,n_stored,round((n_stored/5000)*100,2)))
                break
    return transactions

# %%
department_ids = [DEPT_CLEANING]
transactions_cleaning = extract_transactions(INPUT_TRANSACTIONS,products,department_ids)
# Out:
# Number of transactions read: 1000
# Numer of transactions stored: 51/5000 (1.02%)
#
# Number of transactions read: 2000
# Numer of transactions stored: 99/5000 (1.98%)
#
# Number of transactions read: 3000
# Numer of transactions stored: 142/5000 (2.84%)
#
# Number of transactions read: 4000
# Numer of transactions stored: 187/5000 (3.74%)
#
# Number of transactions read: 5000
# Numer of transactions stored: 229/5000 (4.58%)
#
# Number of transactions read: 6000
# Numer of transactions stored: 285/5000 (5.7%)
#
# Number of transactions read: 7000
# Numer of transactions stored: 338/5000 (6.76%)
#
# Number of transactions read: 8000
# Numer of transactions stored: 381/5000 (7.62%)
#
# Number of transactions read: 9000
# Numer of transactions stored: 434/5000 (8.68%)
#
# Number of transactions read: 10000
# Numer of transactions stored: 481/5000 (9.62%)
#
# Number of transactions read: 11000
# Numer of transactions stored: 537/5000 (10.74%)
#
# Number of transactions read: 12000
# Numer of transactions stored: 582/5000 (11.64%)
#
# Number of transactions read: 13000
# Numer of transactions stored: 632/5000 (12.64%)
#
# Number of transactions read: 14000
# Numer of transactions stored: 678/5000 (13.56%)
#
# Number of transactions read: 15000
# Numer of transactions stored: 716/5000 (14.32%)
#
# Number of transactions read: 16000
# Numer of transactions stored: 761/5000 (15.22%)
#
# Number of transactions read: 17000
# Numer of transactions stored: 815/5000 (16.3%)
#
# Number of transactions read: 18000
# Numer of transactions stored: 869/5000 (17.38%)
#
# Number of transactions read: 19000
# Numer of transactions stored: 921/5000 (18.42%)
#
# Number of transactions read: 20000
# Numer of transactions stored: 959/5000 (19.18%)
#
# Number of transactions read: 21000
# Numer of transactions stored: 1000/5000 (20.0%)
#
# Number of transactions read: 22000
# Numer of transactions stored: 1042/5000 (20.84%)
#
# Number of transactions read: 23000
# Numer of transactions stored: 1092/5000 (21.84%)
#
# Number of transactions read: 24000
# Numer of transactions stored: 1139/5000 (22.78%)
#
# Number of transactions read: 25000
# Numer of transactions stored: 1190/5000 (23.8%)
#
# Number of transactions read: 26000
# Numer of transactions stored: 1238/5000 (24.76%)
#
# Number of transactions read: 27000
# Numer of transactions stored: 1290/5000 (25.8%)
#
# Number of transactions read: 28000
# Numer of transactions stored: 1337/5000 (26.74%)
#
# Number of transactions read: 29000
# Numer of transactions stored: 1377/5000 (27.54%)
#
# Number of transactions read: 30000
# Numer of transactions stored: 1421/5000 (28.42%)
#
# Number of transactions read: 31000
# Numer of transactions stored: 1470/5000 (29.4%)
#
# Number of transactions read: 32000
# Numer of transactions stored: 1515/5000 (30.3%)
#
# Number of transactions read: 33000
# Numer of transactions stored: 1558/5000 (31.16%)
#
# Number of transactions read: 34000
# Numer of transactions stored: 1588/5000 (31.76%)
#
# Number of transactions read: 35000
# Numer of transactions stored: 1641/5000 (32.82%)
#
# Number of transactions read: 36000
# Numer of transactions stored: 1695/5000 (33.9%)
#
# Number of transactions read: 37000
# Numer of transactions stored: 1742/5000 (34.84%)
#
# Number of transactions read: 38000
# Numer of transactions stored: 1772/5000 (35.44%)
#
# Number of transactions read: 39000
# Numer of transactions stored: 1836/5000 (36.72%)
#
# Number of transactions read: 40000
# Numer of transactions stored: 1873/5000 (37.46%)
#
# Number of transactions read: 41000
# Numer of transactions stored: 1916/5000 (38.32%)
#
# Number of transactions read: 42000
# Numer of transactions stored: 1957/5000 (39.14%)
#
# Number of transactions read: 43000
# Numer of transactions stored: 2030/5000 (40.6%)
#
# Number of transactions read: 44000
# Numer of transactions stored: 2091/5000 (41.82%)
#
# Number of transactions read: 45000
# Numer of transactions stored: 2137/5000 (42.74%)
#
# Number of transactions read: 46000
# Numer of transactions stored: 2182/5000 (43.64%)
#
# Number of transactions read: 47000
# Numer of transactions stored: 2229/5000 (44.58%)
#
# Number of transactions read: 48000
# Numer of transactions stored: 2282/5000 (45.64%)
#
# Number of transactions read: 49000
# Numer of transactions stored: 2322/5000 (46.44%)
#
# Number of transactions read: 50000
# Numer of transactions stored: 2363/5000 (47.26%)
#
# Number of transactions read: 51000
# Numer of transactions stored: 2418/5000 (48.36%)
#
# Number of transactions read: 52000
# Numer of transactions stored: 2461/5000 (49.22%)
#
# Number of transactions read: 53000
# Numer of transactions stored: 2506/5000 (50.12%)
#
# Number of transactions read: 54000
# Numer of transactions stored: 2557/5000 (51.14%)
#
# Number of transactions read: 55000
# Numer of transactions stored: 2608/5000 (52.16%)
#
# Number of transactions read: 56000
# Numer of transactions stored: 2647/5000 (52.94%)
#
# Number of transactions read: 57000
# Numer of transactions stored: 2699/5000 (53.98%)
#
# Number of transactions read: 58000
# Numer of transactions stored: 2745/5000 (54.9%)
#
# Number of transactions read: 59000
# Numer of transactions stored: 2799/5000 (55.98%)
#
# Number of transactions read: 60000
# Numer of transactions stored: 2836/5000 (56.72%)
#
# Number of transactions read: 61000
# Numer of transactions stored: 2881/5000 (57.62%)
#
# Number of transactions read: 62000
# Numer of transactions stored: 2925/5000 (58.5%)
#
# Number of transactions read: 63000
# Numer of transactions stored: 2964/5000 (59.28%)
#
# Number of transactions read: 64000
# Numer of transactions stored: 3015/5000 (60.3%)
#
# Number of transactions read: 65000
# Numer of transactions stored: 3057/5000 (61.14%)
#
# Number of transactions read: 66000
# Numer of transactions stored: 3106/5000 (62.12%)
#
# Number of transactions read: 67000
# Numer of transactions stored: 3159/5000 (63.18%)
#
# Number of transactions read: 68000
# Numer of transactions stored: 3219/5000 (64.38%)
#
# Number of transactions read: 69000
# Numer of transactions stored: 3269/5000 (65.38%)
#
# Number of transactions read: 70000
# Numer of transactions stored: 3309/5000 (66.18%)
#
# Number of transactions read: 71000
# Numer of transactions stored: 3357/5000 (67.14%)
#
# Number of transactions read: 72000
# Numer of transactions stored: 3404/5000 (68.08%)
#
# Number of transactions read: 73000
# Numer of transactions stored: 3443/5000 (68.86%)
#
# Number of transactions read: 74000
# Numer of transactions stored: 3489/5000 (69.78%)
#
# Number of transactions read: 75000
# Numer of transactions stored: 3527/5000 (70.54%)
#
# Number of transactions read: 76000
# Numer of transactions stored: 3570/5000 (71.4%)
#
# Number of transactions read: 77000
# Numer of transactions stored: 3635/5000 (72.7%)
#
# Number of transactions read: 78000
# Numer of transactions stored: 3688/5000 (73.76%)
#
# Number of transactions read: 79000
# Numer of transactions stored: 3736/5000 (74.72%)
#
# Number of transactions read: 80000
# Numer of transactions stored: 3781/5000 (75.62%)
#
# Number of transactions read: 81000
# Numer of transactions stored: 3825/5000 (76.5%)
#
# Number of transactions read: 82000
# Numer of transactions stored: 3870/5000 (77.4%)
#
# Number of transactions read: 83000
# Numer of transactions stored: 3923/5000 (78.46%)
#
# Number of transactions read: 84000
# Numer of transactions stored: 3964/5000 (79.28%)
#
# Number of transactions read: 85000
# Numer of transactions stored: 4007/5000 (80.14%)
#
# Number of transactions read: 86000
# Numer of transactions stored: 4058/5000 (81.16%)
#
# Number of transactions read: 87000
# Numer of transactions stored: 4102/5000 (82.04%)
#
# Number of transactions read: 88000
# Numer of transactions stored: 4154/5000 (83.08%)
#
# Number of transactions read: 89000
# Numer of transactions stored: 4204/5000 (84.08%)
#
# Number of transactions read: 90000
# Numer of transactions stored: 4251/5000 (85.02%)
#
# Number of transactions read: 91000
# Numer of transactions stored: 4303/5000 (86.06%)
#
# Number of transactions read: 92000
# Numer of transactions stored: 4360/5000 (87.2%)
#
# Number of transactions read: 93000
# Numer of transactions stored: 4413/5000 (88.26%)
#
# Number of transactions read: 94000
# Numer of transactions stored: 4464/5000 (89.28%)
#
# Number of transactions read: 95000
# Numer of transactions stored: 4521/5000 (90.42%)
#
# Number of transactions read: 96000
# Numer of transactions stored: 4562/5000 (91.24%)
#
# Number of transactions read: 97000
# Numer of transactions stored: 4617/5000 (92.34%)
#
# Number of transactions read: 98000
# Numer of transactions stored: 4658/5000 (93.16%)
#
# Number of transactions read: 99000
# Numer of transactions stored: 4713/5000 (94.26%)
#
# Number of transactions read: 100000
# Numer of transactions stored: 4756/5000 (95.12%)
#
# Number of transactions read: 101000
# Numer of transactions stored: 4797/5000 (95.94%)
#
# Number of transactions read: 102000
# Numer of transactions stored: 4856/5000 (97.12%)
#
# Number of transactions read: 103000
# Numer of transactions stored: 4900/5000 (98.0%)
#
# Number of transactions read: 104000
# Numer of transactions stored: 4951/5000 (99.02%)
#
# Number of transactions read: 104996
# Numer of transactions stored: 5000/5000 (100.0%)
#
# Transactions extracted succesfuly!

# %% [markdown]
# ## 2.3. Extract association rules and comment on them (DEPT_CLEANING)

# %%
results = list(apriori(transactions_cleaning, min_support=0.001, min_confidence=0.5, min_lift=1.0)) 
print_apyori_output(results, products, 'product_name')
# Out:
# Rules involving itemset [18229, 21653]
# ['Plastic Knives'] => ['Compostable Forks'] (support=0.0016, confidence=0.89, lift=123.46)
#
# Rules involving itemset [31801, 18229]
# ['Plastic Knives'] => ['9 Inch Plates'] (support=0.0010, confidence=0.56, lift=48.73)
#
# Rules involving itemset [41387, 18229]
# ['Plastic Knives'] => ['Plastic Spoons'] (support=0.0014, confidence=0.78, lift=111.11)
#
# Rules involving itemset [41387, 21653]
# ['Compostable Forks'] => ['Plastic Spoons'] (support=0.0036, confidence=0.50, lift=71.43)
# ['Plastic Spoons'] => ['Compostable Forks'] (support=0.0036, confidence=0.51, lift=71.43)
#
# Rules involving itemset [28626, 43534]
# ['Foam Bowls'] => ['Foam Plates'] (support=0.0010, confidence=0.62, lift=240.38)
#
# Rules involving itemset [31801, 29474]
# ['Bowls'] => ['9 Inch Plates'] (support=0.0022, confidence=0.52, lift=45.95)
#
# Rules involving itemset [44643, 31066, 17747]
# ['Gallon Freezer Bags', 'Plastic Wrap'] => ['Aluminum Foil'] (support=0.0010, confidence=0.62, lift=17.76)
#
# Rules involving itemset [41387, 18229, 21653]
# ['Plastic Knives'] => ['Plastic Spoons', 'Compostable Forks'] (support=0.0014, confidence=0.78, lift=216.05)
# ['Plastic Knives', 'Compostable Forks'] => ['Plastic Spoons'] (support=0.0014, confidence=0.88, lift=125.00)
# ['Plastic Spoons', 'Plastic Knives'] => ['Compostable Forks'] (support=0.0014, confidence=1.00, lift=138.89)
#
# Rules involving itemset [29474, 41387, 21653]
# ['Bowls', 'Compostable Forks'] => ['Plastic Spoons'] (support=0.0012, confidence=0.67, lift=95.24)
# ['Bowls', 'Plastic Spoons'] => ['Compostable Forks'] (support=0.0012, confidence=0.86, lift=119.05)

# %% [markdown]
# <font size="+1" >As we can clearly see we should recomend to anyone who buys any type plastic cutlery the other parts of the cutlery with a high confidence. For example everybody that have bought plastic spoons and knives have bought compostable forks too. Also the ones who have bought bowls and compostable forks or spoons tend to buy also the remaining item with high confidence. It is also common to buy aluminum foil while buying gallon freezer bags and plastic wrap. There are also 1 to 1 recomendations such as if they buy plastic spoons would be a good idea to recommend compostable forks and viceversa. There are some more recommendations but these are a few examples of the potential of association rules.</font>

# %% [markdown]
# ## 2.4. Extract association rules and comment on them (other departments)

# %%
department_ids = [DEPT_DRINKS,DEPT_ALCOHOL]
transactions_drinks = extract_transactions(INPUT_TRANSACTIONS,products,department_ids)
# Out:
# Number of transactions read: 1000
# Numer of transactions stored: 195/5000 (3.9%)
#
# Number of transactions read: 2000
# Numer of transactions stored: 380/5000 (7.6%)
#
# Number of transactions read: 3000
# Numer of transactions stored: 608/5000 (12.16%)
#
# Number of transactions read: 4000
# Numer of transactions stored: 818/5000 (16.36%)
#
# Number of transactions read: 5000
# Numer of transactions stored: 1026/5000 (20.52%)
#
# Number of transactions read: 6000
# Numer of transactions stored: 1241/5000 (24.82%)
#
# Number of transactions read: 7000
# Numer of transactions stored: 1448/5000 (28.96%)
#
# Number of transactions read: 8000
# Numer of transactions stored: 1682/5000 (33.64%)
#
# Number of transactions read: 9000
# Numer of transactions stored: 1882/5000 (37.64%)
#
# Number of transactions read: 10000
# Numer of transactions stored: 2109/5000 (42.18%)
#
# Number of transactions read: 11000
# Numer of transactions stored: 2326/5000 (46.52%)
#
# Number of transactions read: 12000
# Numer of transactions stored: 2544/5000 (50.88%)
#
# Number of transactions read: 13000
# Numer of transactions stored: 2767/5000 (55.34%)
#
# Number of transactions read: 14000
# Numer of transactions stored: 2969/5000 (59.38%)
#
# Number of transactions read: 15000
# Numer of transactions stored: 3174/5000 (63.48%)
#
# Number of transactions read: 16000
# Numer of transactions stored: 3373/5000 (67.46%)
#
# Number of transactions read: 17000
# Numer of transactions stored: 3573/5000 (71.46%)
#
# Number of transactions read: 18000
# Numer of transactions stored: 3777/5000 (75.54%)
#
# Number of transactions read: 19000
# Numer of transactions stored: 3994/5000 (79.88%)
#
# Number of transactions read: 20000
# Numer of transactions stored: 4194/5000 (83.88%)
#
# Number of transactions read: 21000
# Numer of transactions stored: 4400/5000 (88.0%)
#
# Number of transactions read: 22000
# Numer of transactions stored: 4616/5000 (92.32%)
#
# Number of transactions read: 23000
# Numer of transactions stored: 4829/5000 (96.58%)
#
# Number of transactions read: 23767
# Numer of transactions stored: 5000/5000 (100.0%)
#
# Transactions extracted succesfuly!

# %%
results = list(apriori(transactions_drinks, min_support=0.003, min_confidence=0.5, min_lift=1.0))
print_apyori_output(results, products, 'product_name')
# Out:
# Rules involving itemset [196, 46149]
# ['Zero Calorie Cola'] => ['Soda'] (support=0.0046, confidence=0.55, lift=17.33)
#
# Rules involving itemset [11123, 31231]
# ['Vitamin Water Zero Rise Orange'] => ['Vitamin Water Zero Squeezed Lemonade'] (support=0.0032, confidence=0.53, lift=72.07)
#
# Rules involving itemset [12576, 39947]
# ['Kiwi Sandia Sparkling Water'] => ['Blackberry Cucumber Sparkling Water'] (support=0.0054, confidence=0.51, lift=39.19)
#
# Rules involving itemset [44632, 14947, 21709]
# ['Pure Sparkling Water', 'Sparkling Lemon Water'] => ['Sparkling Water Grapefruit'] (support=0.0040, confidence=0.61, lift=8.30)
#
# Rules involving itemset [44632, 14947, 35221]
# ['Pure Sparkling Water', 'Lime Sparkling Water'] => ['Sparkling Water Grapefruit'] (support=0.0046, confidence=0.72, lift=9.85)
#
# Rules involving itemset [44632, 21709, 20119]
# ['Sparkling Lemon Water', 'Sparkling Water Berry'] => ['Sparkling Water Grapefruit'] (support=0.0034, confidence=0.63, lift=8.63)
#
# Rules involving itemset [44632, 35221, 20119]
# ['Lime Sparkling Water', 'Sparkling Water Berry'] => ['Sparkling Water Grapefruit'] (support=0.0034, confidence=0.74, lift=10.13)
#
# Rules involving itemset [44632, 21709, 35221]
# ['Sparkling Lemon Water', 'Lime Sparkling Water'] => ['Sparkling Water Grapefruit'] (support=0.0056, confidence=0.52, lift=7.10)

# %% [markdown]
# <font size="+1">Thanks to the association ruls we can recomend with a good confidence level to the ones who bought two types of Sparkling Water, recommend them another type because we can clearly see that people who bought for example two of the following: Pure Sparkling Water, Sparkling Lemon Water, Lime Sparkling Water and/or Sparkling Water Berry tend to buy also Sparkling Water Grapefruit. It is also frequent to the ones who buy some kind of soda such as Zero Calorie Cola buy also Soda. As we have seen it seems to follow some kind of pattern in which people who buy one drink they also buy another type too.</font>

# %% [markdown]
# # EXTRA

# %%
def print_apyori_output_difdep(association_results, info=False, info_key=False): # Function that only prints rules of different departments
    for relation_record in association_results:
        itemset = list(relation_record.items)
        
        # Consider only itemsets of two elements
        if len(itemset) > 1: 
        
            not_printed = True # Bool var to print only one time
            for rules in relation_record.ordered_statistics:
                antecedent = list(rules.items_base)
                consequent = list(rules.items_add)
                antecedent_dep = []
                diff_dep = False 
                
                for item in antecedent: # Extract departments of antecedents
                    antecedent_dep.append(info.loc[item].department_id)
                
                for item in consequent: # Checks for every item of consequent if it does not belong to a department of antecedents
                    department = info.loc[item].department_id
                    if department not in antecedent_dep:
                        diff_dep = True # If it does not belongs a bool var is changed to true and the loop is broken
                        break
                
                if info_key:
                    antecedent = [info.loc[x][info_key] for x in antecedent]
                    consequent = [info.loc[x][info_key] for x in consequent]
                if diff_dep: # It only will print the relations if they are between different departments
                    if not_printed: # things to print only one time
                        print()
                        print("Rules involving itemset %s" % itemset)
                        support = relation_record.support
                        not_printed = False
                    
                    confidence = rules.confidence
                    lift = rules.lift

                    print("%s => %s (support=%.4f, confidence=%.2f, lift=%.2f)" %
                          (antecedent, consequent, support, confidence, lift))

# %%
department_ids = [DEPT_VEGGIES,DEPT_BAKERY]
transactions_vegbak = extract_transactions(INPUT_TRANSACTIONS,products,department_ids)
print("\n\n INVOLVED RULES\n----------------")
results = list(apriori(transactions_vegbak, min_support=0.001, min_confidence=0.5, min_lift=1.0))
print_apyori_output_difdep(results, products, 'product_name')
# Out:
# Number of transactions read: 1000
# Numer of transactions stored: 659/5000 (13.18%)
#
# Number of transactions read: 2000
# Numer of transactions stored: 1267/5000 (25.34%)
#
# Number of transactions read: 3000
# Numer of transactions stored: 1898/5000 (37.96%)
#
# Number of transactions read: 4000
# Numer of transactions stored: 2515/5000 (50.3%)
#
# Number of transactions read: 5000
# Numer of transactions stored: 3134/5000 (62.68%)
#
# Number of transactions read: 6000
# Numer of transactions stored: 3744/5000 (74.88%)
#
# Number of transactions read: 7000
# Numer of transactions stored: 4367/5000 (87.34%)
#
# Number of transactions read: 8000
# Numer of transactions stored: 4994/5000 (99.88%)
#
# Number of transactions read: 8010
# Numer of transactions stored: 5000/5000 (100.0%)
#
# Transactions extracted succesfuly!
#
#
#  INVOLVED RULES
# ----------------
#
# Rules involving itemset [12258, 21903]
# ['Organic White English Muffins'] => ['Organic Baby Spinach'] (support=0.0010, confidence=0.50, lift=4.55)
#
# Rules involving itemset [13176, 30252]
# ['Organic Soft Wheat Bread'] => ['Bag of Organic Bananas'] (support=0.0012, confidence=0.67, lift=3.81)
#
# Rules involving itemset [13176, 36397]
# ['Gluten Free Millet-Chia Bread'] => ['Bag of Organic Bananas'] (support=0.0012, confidence=0.50, lift=2.86)
#
# Rules involving itemset [13176, 44310]
# ['Soft Pretzel Mini Buns'] => ['Bag of Organic Bananas'] (support=0.0010, confidence=0.50, lift=2.86)
#
# Rules involving itemset [13176, 44533]
# ['French Baguettes, Take & Bake, Twin Pack'] => ['Bag of Organic Bananas'] (support=0.0010, confidence=0.50, lift=2.86)
#
# Rules involving itemset [29553, 24852]
# ['Super Soft Taco Flour Tortillas'] => ['Banana'] (support=0.0016, confidence=0.50, lift=2.28)
#
# Rules involving itemset [45948, 24852]
# ['Gluten Free 7 Grain Bread'] => ['Banana'] (support=0.0020, confidence=0.50, lift=2.28)

# %%
department_ids = [DEPT_PHARMACY,DEPT_CLEANING, DEPT_WORLD]
transactions_pcw = extract_transactions(INPUT_TRANSACTIONS,products,department_ids)
print("\n\n INVOLVED RULES\n----------------")
results = list(apriori(transactions_pcw, min_support=0.0008, min_confidence=0.1, min_lift=1.0))
print_apyori_output_difdep(results, products, 'product_name')
# Out:
# Number of transactions read: 1000
# Numer of transactions stored: 107/5000 (2.14%)
#
# Number of transactions read: 2000
# Numer of transactions stored: 207/5000 (4.14%)
#
# Number of transactions read: 3000
# Numer of transactions stored: 299/5000 (5.98%)
#
# Number of transactions read: 4000
# Numer of transactions stored: 392/5000 (7.84%)
#
# Number of transactions read: 5000
# Numer of transactions stored: 492/5000 (9.84%)
#
# Number of transactions read: 6000
# Numer of transactions stored: 606/5000 (12.12%)
#
# Number of transactions read: 7000
# Numer of transactions stored: 706/5000 (14.12%)
#
# Number of transactions read: 8000
# Numer of transactions stored: 796/5000 (15.92%)
#
# Number of transactions read: 9000
# Numer of transactions stored: 908/5000 (18.16%)
#
# Number of transactions read: 10000
# Numer of transactions stored: 1013/5000 (20.26%)
#
# Number of transactions read: 11000
# Numer of transactions stored: 1137/5000 (22.74%)
#
# Number of transactions read: 12000
# Numer of transactions stored: 1226/5000 (24.52%)
#
# Number of transactions read: 13000
# Numer of transactions stored: 1330/5000 (26.6%)
#
# Number of transactions read: 14000
# Numer of transactions stored: 1432/5000 (28.64%)
#
# Number of transactions read: 15000
# Numer of transactions stored: 1526/5000 (30.52%)
#
# Number of transactions read: 16000
# Numer of transactions stored: 1623/5000 (32.46%)
#
# Number of transactions read: 17000
# Numer of transactions stored: 1724/5000 (34.48%)
#
# Number of transactions read: 18000
# Numer of transactions stored: 1835/5000 (36.7%)
#
# Number of transactions read: 19000
# Numer of transactions stored: 1934/5000 (38.68%)
#
# Number of transactions read: 20000
# Numer of transactions stored: 2028/5000 (40.56%)
#
# Number of transactions read: 21000
# Numer of transactions stored: 2134/5000 (42.68%)
#
# Number of transactions read: 22000
# Numer of transactions stored: 2228/5000 (44.56%)
#
# Number of transactions read: 23000
# Numer of transactions stored: 2325/5000 (46.5%)
#
# Number of transactions read: 24000
# Numer of transactions stored: 2441/5000 (48.82%)
#
# Number of transactions read: 25000
# Numer of transactions stored: 2550/5000 (51.0%)
#
# Number of transactions read: 26000
# Numer of transactions stored: 2653/5000 (53.06%)
#
# Number of transactions read: 27000
# Numer of transactions stored: 2756/5000 (55.12%)
#
# Number of transactions read: 28000
# Numer of transactions stored: 2859/5000 (57.18%)
#
# Number of transactions read: 29000
# Numer of transactions stored: 2949/5000 (58.98%)
#
# Number of transactions read: 30000
# Numer of transactions stored: 3039/5000 (60.78%)
#
# Number of transactions read: 31000
# Numer of transactions stored: 3129/5000 (62.58%)
#
# Number of transactions read: 32000
# Numer of transactions stored: 3244/5000 (64.88%)
#
# Number of transactions read: 33000
# Numer of transactions stored: 3339/5000 (66.78%)
#
# Number of transactions read: 34000
# Numer of transactions stored: 3418/5000 (68.36%)
#
# Number of transactions read: 35000
# Numer of transactions stored: 3521/5000 (70.42%)
#
# Number of transactions read: 36000
# Numer of transactions stored: 3637/5000 (72.74%)
#
# Number of transactions read: 37000
# Numer of transactions stored: 3741/5000 (74.82%)
#
# Number of transactions read: 38000
# Numer of transactions stored: 3829/5000 (76.58%)
#
# Number of transactions read: 39000
# Numer of transactions stored: 3936/5000 (78.72%)
#
# Number of transactions read: 40000
# Numer of transactions stored: 4021/5000 (80.42%)
#
# Number of transactions read: 41000
# Numer of transactions stored: 4106/5000 (82.12%)
#
# Number of transactions read: 42000
# Numer of transactions stored: 4195/5000 (83.9%)
#
# Number of transactions read: 43000
# Numer of transactions stored: 4320/5000 (86.4%)
#
# Number of transactions read: 44000
# Numer of transactions stored: 4438/5000 (88.76%)
#
# Number of transactions read: 45000
# Numer of transactions stored: 4542/5000 (90.84%)
#
# Number of transactions read: 46000
# Numer of transactions stored: 4638/5000 (92.76%)
#
# Number of transactions read: 47000
# Numer of transactions stored: 4736/5000 (94.72%)
#
# Number of transactions read: 48000
# Numer of transactions stored: 4857/5000 (97.14%)
#
# Number of transactions read: 49000
# Numer of transactions stored: 4936/5000 (98.72%)
#
# Number of transactions read: 49710
# Numer of transactions stored: 5000/5000 (100.0%)
#
# Transactions extracted succesfuly!
#
#
#  INVOLVED RULES
# ----------------
#
# Rules involving itemset [39162, 2086]
# ['Clean Day Basil Hand Soap'] => ['Sustainably Soft Bath Tissue'] (support=0.0008, confidence=0.10, lift=3.33)
#
# Rules involving itemset [12312, 46413]
# ['Lavender Scent Laundry Detergent'] => ['Lavender Hand Soap'] (support=0.0008, confidence=0.29, lift=27.47)
#
# Rules involving itemset [39162, 12442]
# ['Basil Dish Soap'] => ['Clean Day Basil Hand Soap'] (support=0.0008, confidence=0.13, lift=17.09)
# ['Clean Day Basil Hand Soap'] => ['Basil Dish Soap'] (support=0.0008, confidence=0.10, lift=17.09)

# %%
department_ids = [DEPT_PETS,DEPT_BABIES]
transactions_petbab = extract_transactions(INPUT_TRANSACTIONS,products,department_ids)
print("\n\n INVOLVED RULES\n----------------")
results = list(apriori(transactions_petbab, min_support=0.0008, min_confidence=0.1, min_lift=1.0))
print_apyori_output_difdep(results, products, 'product_name')
# Out:
# Number of transactions read: 1000
# Numer of transactions stored: 31/5000 (0.62%)
#
# Number of transactions read: 2000
# Numer of transactions stored: 65/5000 (1.3%)
#
# Number of transactions read: 3000
# Numer of transactions stored: 102/5000 (2.04%)
#
# Number of transactions read: 4000
# Numer of transactions stored: 138/5000 (2.76%)
#
# Number of transactions read: 5000
# Numer of transactions stored: 173/5000 (3.46%)
#
# Number of transactions read: 6000
# Numer of transactions stored: 203/5000 (4.06%)
#
# Number of transactions read: 7000
# Numer of transactions stored: 238/5000 (4.76%)
#
# Number of transactions read: 8000
# Numer of transactions stored: 266/5000 (5.32%)
#
# Number of transactions read: 9000
# Numer of transactions stored: 297/5000 (5.94%)
#
# Number of transactions read: 10000
# Numer of transactions stored: 335/5000 (6.7%)
#
# Number of transactions read: 11000
# Numer of transactions stored: 368/5000 (7.36%)
#
# Number of transactions read: 12000
# Numer of transactions stored: 404/5000 (8.08%)
#
# Number of transactions read: 13000
# Numer of transactions stored: 440/5000 (8.8%)
#
# Number of transactions read: 14000
# Numer of transactions stored: 479/5000 (9.58%)
#
# Number of transactions read: 15000
# Numer of transactions stored: 514/5000 (10.28%)
#
# Number of transactions read: 16000
# Numer of transactions stored: 550/5000 (11.0%)
#
# Number of transactions read: 17000
# Numer of transactions stored: 584/5000 (11.68%)
#
# Number of transactions read: 18000
# Numer of transactions stored: 616/5000 (12.32%)
#
# Number of transactions read: 19000
# Numer of transactions stored: 642/5000 (12.84%)
#
# Number of transactions read: 20000
# Numer of transactions stored: 678/5000 (13.56%)
#
# Number of transactions read: 21000
# Numer of transactions stored: 714/5000 (14.28%)
#
# Number of transactions read: 22000
# Numer of transactions stored: 747/5000 (14.94%)
#
# Number of transactions read: 23000
# Numer of transactions stored: 784/5000 (15.68%)
#
# Number of transactions read: 24000
# Numer of transactions stored: 823/5000 (16.46%)
#
# Number of transactions read: 25000
# Numer of transactions stored: 856/5000 (17.12%)
#
# Number of transactions read: 26000
# Numer of transactions stored: 895/5000 (17.9%)
#
# Number of transactions read: 27000
# Numer of transactions stored: 926/5000 (18.52%)
#
# Number of transactions read: 28000
# Numer of transactions stored: 957/5000 (19.14%)
#
# Number of transactions read: 29000
# Numer of transactions stored: 991/5000 (19.82%)
#
# Number of transactions read: 30000
# Numer of transactions stored: 1024/5000 (20.48%)
#
# Number of transactions read: 31000
# Numer of transactions stored: 1047/5000 (20.94%)
#
# Number of transactions read: 32000
# Numer of transactions stored: 1078/5000 (21.56%)
#
# Number of transactions read: 33000
# Numer of transactions stored: 1105/5000 (22.1%)
#
# Number of transactions read: 34000
# Numer of transactions stored: 1129/5000 (22.58%)
#
# Number of transactions read: 35000
# Numer of transactions stored: 1168/5000 (23.36%)
#
# Number of transactions read: 36000
# Numer of transactions stored: 1197/5000 (23.94%)
#
# Number of transactions read: 37000
# Numer of transactions stored: 1235/5000 (24.7%)
#
# Number of transactions read: 38000
# Numer of transactions stored: 1258/5000 (25.16%)
#
# Number of transactions read: 39000
# Numer of transactions stored: 1293/5000 (25.86%)
#
# Number of transactions read: 40000
# Numer of transactions stored: 1326/5000 (26.52%)
#
# Number of transactions read: 41000
# Numer of transactions stored: 1363/5000 (27.26%)
#
# Number of transactions read: 42000
# Numer of transactions stored: 1388/5000 (27.76%)
#
# Number of transactions read: 43000
# Numer of transactions stored: 1424/5000 (28.48%)
#
# Number of transactions read: 44000
# Numer of transactions stored: 1451/5000 (29.02%)
#
# Number of transactions read: 45000
# Numer of transactions stored: 1473/5000 (29.46%)
#
# Number of transactions read: 46000
# Numer of transactions stored: 1498/5000 (29.96%)
#
# Number of transactions read: 47000
# Numer of transactions stored: 1534/5000 (30.68%)
#
# Number of transactions read: 48000
# Numer of transactions stored: 1564/5000 (31.28%)
#
# Number of transactions read: 49000
# Numer of transactions stored: 1596/5000 (31.92%)
#
# Number of transactions read: 50000
# Numer of transactions stored: 1625/5000 (32.5%)
#
# Number of transactions read: 51000
# Numer of transactions stored: 1659/5000 (33.18%)
#
# Number of transactions read: 52000
# Numer of transactions stored: 1677/5000 (33.54%)
#
# Number of transactions read: 53000
# Numer of transactions stored: 1700/5000 (34.0%)
#
# Number of transactions read: 54000
# Numer of transactions stored: 1726/5000 (34.52%)
#
# Number of transactions read: 55000
# Numer of transactions stored: 1749/5000 (34.98%)
#
# Number of transactions read: 56000
# Numer of transactions stored: 1777/5000 (35.54%)
#
# Number of transactions read: 57000
# Numer of transactions stored: 1807/5000 (36.14%)
#
# Number of transactions read: 58000
# Numer of transactions stored: 1845/5000 (36.9%)
#
# Number of transactions read: 59000
# Numer of transactions stored: 1879/5000 (37.58%)
#
# Number of transactions read: 60000
# Numer of transactions stored: 1907/5000 (38.14%)
#
# Number of transactions read: 61000
# Numer of transactions stored: 1950/5000 (39.0%)
#
# Number of transactions read: 62000
# Numer of transactions stored: 1986/5000 (39.72%)
#
# Number of transactions read: 63000
# Numer of transactions stored: 2011/5000 (40.22%)
#
# Number of transactions read: 64000
# Numer of transactions stored: 2046/5000 (40.92%)
#
# Number of transactions read: 65000
# Numer of transactions stored: 2067/5000 (41.34%)
#
# Number of transactions read: 66000
# Numer of transactions stored: 2098/5000 (41.96%)
#
# Number of transactions read: 67000
# Numer of transactions stored: 2132/5000 (42.64%)
#
# Number of transactions read: 68000
# Numer of transactions stored: 2166/5000 (43.32%)
#
# Number of transactions read: 69000
# Numer of transactions stored: 2192/5000 (43.84%)
#
# Number of transactions read: 70000
# Numer of transactions stored: 2228/5000 (44.56%)
#
# Number of transactions read: 71000
# Numer of transactions stored: 2250/5000 (45.0%)
#
# Number of transactions read: 72000
# Numer of transactions stored: 2282/5000 (45.64%)
#
# Number of transactions read: 73000
# Numer of transactions stored: 2312/5000 (46.24%)
#
# Number of transactions read: 74000
# Numer of transactions stored: 2342/5000 (46.84%)
#
# Number of transactions read: 75000
# Numer of transactions stored: 2382/5000 (47.64%)
#
# Number of transactions read: 76000
# Numer of transactions stored: 2415/5000 (48.3%)
#
# Number of transactions read: 77000
# Numer of transactions stored: 2443/5000 (48.86%)
#
# Number of transactions read: 78000
# Numer of transactions stored: 2470/5000 (49.4%)
#
# Number of transactions read: 79000
# Numer of transactions stored: 2507/5000 (50.14%)
#
# Number of transactions read: 80000
# Numer of transactions stored: 2543/5000 (50.86%)
#
# Number of transactions read: 81000
# Numer of transactions stored: 2574/5000 (51.48%)
#
# Number of transactions read: 82000
# Numer of transactions stored: 2609/5000 (52.18%)
#
# Number of transactions read: 83000
# Numer of transactions stored: 2636/5000 (52.72%)
#
# Number of transactions read: 84000
# Numer of transactions stored: 2667/5000 (53.34%)
#
# Number of transactions read: 85000
# Numer of transactions stored: 2691/5000 (53.82%)
#
# Number of transactions read: 86000
# Numer of transactions stored: 2726/5000 (54.52%)
#
# Number of transactions read: 87000
# Numer of transactions stored: 2752/5000 (55.04%)
#
# Number of transactions read: 88000
# Numer of transactions stored: 2776/5000 (55.52%)
#
# Number of transactions read: 89000
# Numer of transactions stored: 2810/5000 (56.2%)
#
# Number of transactions read: 90000
# Numer of transactions stored: 2850/5000 (57.0%)
#
# Number of transactions read: 91000
# Numer of transactions stored: 2886/5000 (57.72%)
#
# Number of transactions read: 92000
# Numer of transactions stored: 2915/5000 (58.3%)
#
# Number of transactions read: 93000
# Numer of transactions stored: 2949/5000 (58.98%)
#
# Number of transactions read: 94000
# Numer of transactions stored: 2986/5000 (59.72%)
#
# Number of transactions read: 95000
# Numer of transactions stored: 3017/5000 (60.34%)
#
# Number of transactions read: 96000
# Numer of transactions stored: 3047/5000 (60.94%)
#
# Number of transactions read: 97000
# Numer of transactions stored: 3083/5000 (61.66%)
#
# Number of transactions read: 98000
# Numer of transactions stored: 3120/5000 (62.4%)
#
# Number of transactions read: 99000
# Numer of transactions stored: 3164/5000 (63.28%)
#
# Number of transactions read: 100000
# Numer of transactions stored: 3190/5000 (63.8%)
#
# Number of transactions read: 101000
# Numer of transactions stored: 3220/5000 (64.4%)
#
# Number of transactions read: 102000
# Numer of transactions stored: 3248/5000 (64.96%)
#
# Number of transactions read: 103000
# Numer of transactions stored: 3279/5000 (65.58%)
#
# Number of transactions read: 104000
# Numer of transactions stored: 3310/5000 (66.2%)
#
# Number of transactions read: 105000
# Numer of transactions stored: 3347/5000 (66.94%)
#
# Number of transactions read: 106000
# Numer of transactions stored: 3388/5000 (67.76%)
#
# Number of transactions read: 107000
# Numer of transactions stored: 3432/5000 (68.64%)
#
# Number of transactions read: 108000
# Numer of transactions stored: 3475/5000 (69.5%)
#
# Number of transactions read: 109000
# Numer of transactions stored: 3507/5000 (70.14%)
#
# Number of transactions read: 110000
# Numer of transactions stored: 3539/5000 (70.78%)
#
# Number of transactions read: 111000
# Numer of transactions stored: 3568/5000 (71.36%)
#
# Number of transactions read: 112000
# Numer of transactions stored: 3598/5000 (71.96%)
#
# Number of transactions read: 113000
# Numer of transactions stored: 3632/5000 (72.64%)
#
# Number of transactions read: 114000
# Numer of transactions stored: 3663/5000 (73.26%)
#
# Number of transactions read: 115000
# Numer of transactions stored: 3696/5000 (73.92%)
#
# Number of transactions read: 116000
# Numer of transactions stored: 3724/5000 (74.48%)
#
# Number of transactions read: 117000
# Numer of transactions stored: 3752/5000 (75.04%)
#
# Number of transactions read: 118000
# Numer of transactions stored: 3786/5000 (75.72%)
#
# Number of transactions read: 119000
# Numer of transactions stored: 3809/5000 (76.18%)
#
# Number of transactions read: 120000
# Numer of transactions stored: 3840/5000 (76.8%)
#
# Number of transactions read: 121000
# Numer of transactions stored: 3877/5000 (77.54%)
#
# Number of transactions read: 122000
# Numer of transactions stored: 3912/5000 (78.24%)
#
# Number of transactions read: 123000
# Numer of transactions stored: 3941/5000 (78.82%)
#
# Number of transactions read: 124000
# Numer of transactions stored: 3976/5000 (79.52%)
#
# Number of transactions read: 125000
# Numer of transactions stored: 3999/5000 (79.98%)
#
# Number of transactions read: 126000
# Numer of transactions stored: 4033/5000 (80.66%)
#
# Number of transactions read: 127000
# Numer of transactions stored: 4058/5000 (81.16%)
#
# Number of transactions read: 128000
# Numer of transactions stored: 4092/5000 (81.84%)
#
# Number of transactions read: 129000
# Numer of transactions stored: 4127/5000 (82.54%)
#
# Number of transactions read: 130000
# Numer of transactions stored: 4149/5000 (82.98%)
#
# Number of transactions read: 131000
# Numer of transactions stored: 4178/5000 (83.56%)
#
# Number of transactions read: 132000
# Numer of transactions stored: 4208/5000 (84.16%)
#
# Number of transactions read: 133000
# Numer of transactions stored: 4240/5000 (84.8%)
#
# Number of transactions read: 134000
# Numer of transactions stored: 4264/5000 (85.28%)
#
# Number of transactions read: 135000
# Numer of transactions stored: 4296/5000 (85.92%)
#
# Number of transactions read: 136000
# Numer of transactions stored: 4332/5000 (86.64%)
#
# Number of transactions read: 137000
# Numer of transactions stored: 4373/5000 (87.46%)
#
# Number of transactions read: 138000
# Numer of transactions stored: 4413/5000 (88.26%)
#
# Number of transactions read: 139000
# Numer of transactions stored: 4452/5000 (89.04%)
#
# Number of transactions read: 140000
# Numer of transactions stored: 4488/5000 (89.76%)
#
# Number of transactions read: 141000
# Numer of transactions stored: 4519/5000 (90.38%)
#
# Number of transactions read: 142000
# Numer of transactions stored: 4557/5000 (91.14%)
#
# Number of transactions read: 143000
# Numer of transactions stored: 4587/5000 (91.74%)
#
# Number of transactions read: 144000
# Numer of transactions stored: 4614/5000 (92.28%)
#
# Number of transactions read: 145000
# Numer of transactions stored: 4644/5000 (92.88%)
#
# Number of transactions read: 146000
# Numer of transactions stored: 4675/5000 (93.5%)
#
# Number of transactions read: 147000
# Numer of transactions stored: 4700/5000 (94.0%)
#
# Number of transactions read: 148000
# Numer of transactions stored: 4733/5000 (94.66%)
#
# Number of transactions read: 149000
# Numer of transactions stored: 4759/5000 (95.18%)
#
# Number of transactions read: 150000
# Numer of transactions stored: 4791/5000 (95.82%)
#
# Number of transactions read: 151000
# Numer of transactions stored: 4830/5000 (96.6%)
#
# Number of transactions read: 152000
# Numer of transactions stored: 4856/5000 (97.12%)
#
# Number of transactions read: 153000
# Numer of transactions stored: 4902/5000 (98.04%)
#
# Number of transactions read: 154000
# Numer of transactions stored: 4933/5000 (98.66%)
#
# Number of transactions read: 155000
# Numer of transactions stored: 4967/5000 (99.34%)
#
# Number of transactions read: 156000
# Numer of transactions stored: 4998/5000 (99.96%)
#
# Number of transactions read: 156022
# Numer of transactions stored: 5000/5000 (100.0%)
#
# Transactions extracted succesfuly!
#
#
#  INVOLVED RULES
# ----------------
#
# Rules involving itemset [7512, 35956]
# ['2nd Foods Ham & Ham Gravy'] => ['Fancy Feast Wet Classic Chicken Feast Cat Food'] (support=0.0008, confidence=0.50, lift=50.00)

# %% [markdown]
# <font size="+1">We have test it with three combinations, first of all Veggies and Bakery where we can clearly see a direct interaction between departments concluding that is common to people who have bought anything in Bakery, for example Organic Soft Wheat Bread, buy something in Veggies such as Bag of Organic Bananas. We also can recommend with high confidence to people who bought something organic in Bakery, like Organic Soft Wheat Bread, to buy Bananas or a Bag of Organic Bananas.
#
# <font size="+1">    The second test is among Pharmacy, Cleaning and World deparments. This relation is much less obvious than the previous one and there is no relation with Pharmacy but a little relation between detergents and dish soaps with hand soap or bath tissues.
#
# <font size="+1">    For the last test, between Pets and Babies, we cannot extract any conclusion more than people who buy 2nd Foods Ham and Ham Gravy tends to buy Fancy Feast Wet Classic Chicken Feast Cat Food from Pets department.
# </font>

# %% [markdown]
# <font size="+2" color="#003300">I hereby declare that, except for the code provided by the course instructors, all of my code, report, and figures were produced by myself.</font>
